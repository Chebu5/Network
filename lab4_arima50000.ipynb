# %% [markdown]
# # импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')
import json
import pickle
import os

# %% [markdown]
# # функция для сохранения результатов

# %%
def save_arima_results(results_dict, best_model_name, forecasts, test_data, test_dates, train_data, ts_data, filename="arima_results.json"):
    """
    сохраняет результаты ARIMA моделей в json файл
    """
    results_to_save = {
        'best_model': best_model_name,
        'models_comparison': {},
        'forecasts': {},
        'test_data_info': {}
    }
    
    # сохраняем метрики для всех моделей
    for model_name, res in results_dict.items():
        if res is not None:
            results_to_save['models_comparison'][model_name] = {
                'rmse': float(res['rmse']),
                'mae': float(res['mae']),
                'mape': float(res['mape']),
                'mse': float(res['mse']),
                'aic': float(res['aic']),
                'bic': float(res['bic'])
            }
    
    # сохраняем прогнозы лучшей модели
    if best_model_name in forecasts and forecasts[best_model_name] is not None:
        # используем test_dates для дат прогнозов
        if hasattr(test_dates, 'strftime'):
            dates_list = test_dates.strftime('%Y-%m-%d %H:%M:%S').tolist()
        else:
            # если test_dates не DatetimeIndex, создаем список строк
            dates_list = [str(date) for date in test_dates]
            
        results_to_save['forecasts'][best_model_name] = {
            'dates': dates_list,
            'values': forecasts[best_model_name].values.tolist()
        }
    
    # сохраняем информацию о тестовых данных
    results_to_save['test_data_info'] = {
        'train_size': len(train_data),
        'test_size': len(test_data),
        'data_period': f"{ts_data.index.min()} до {ts_data.index.max()}",
        'train_period': f"{train_data.index.min()} до {train_data.index.max()}" if hasattr(train_data.index, 'min') else "недоступно",
        'test_period': f"{test_dates.min()} до {test_dates.max()}" if hasattr(test_dates, 'min') else "недоступно"
    }
    
    # сохраняем в json файл
    with open(filename, 'w') as f:
        json.dump(results_to_save, f, indent=4, ensure_ascii=False)
    
    print(f"\nрезультаты сохранены в файл: {filename}")
    
    return results_to_save

# %% [markdown]
# # загрузка и подготовка данных

# %%
# загружаем те же данные, что используются в LSTM модели
print("загрузка данных...")
data = pd.read_csv('bitcoin_2017_to_2023.csv')

# преобразуем timestamp в datetime и устанавливаем как индекс
data['timestamp'] = pd.to_datetime(data['timestamp'])
data.set_index('timestamp', inplace=True)

# для ARIMA нам нужен только временной ряд цены (возьмем 'low' как в LSTM моделях)
ts_data = data['low'].copy()

print("\n информация о временном ряде ")
print(f"размер временного ряда: {len(ts_data)}")
print(f"период данных: {ts_data.index.min()} до {ts_data.index.max()}")
print(f"частота данных: {pd.infer_freq(ts_data.index[:10])}")
# Out:
# загрузка данных...
#
#  информация о временном ряде
# размер временного ряда: 3126000
# период данных: 2017-08-17 04:00:00 до 2023-08-01 13:19:00
# частота данных: -1min

# %% [markdown]
# # визуализация исходных данных

# %%
plt.figure(figsize=(14, 6))
plt.plot(ts_data, linewidth=0.5)
plt.title('динамика минимальной цены биткоина (low) 2017-2023')
plt.xlabel('дата')
plt.ylabel('цена (usd)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # проверка стационарности

# %%
# для того, чтобы использовать ARIMA, необходим стационарный временной ряд
# по сути, стоимость криптовалюты не является таким, потому что имеет места с явным ростом или падением
# может зависеть от событий в мире, например, из-за чего также будет наблюдаться изменение среднего значения со временем
# в статье об этом ничего нет

# def check_stationarity(timeseries):
#     """проверяет стационарность временного ряда с помощью теста дикки-фуллера"""
#     result = adfuller(timeseries.dropna())
#     print('результаты теста дикки-фуллера:')
#     print(f'статистика: {result[0]:.4f}')
#     print(f'p-value: {result[1]:.4f}')
    
#     if result[1] <= 0.05:
#         print("вывод: ряд стационарен (p-value ≤ 0.05)")
#         return True
#     else:
#         print("вывод: ряд нестационарен (p-value > 0.05)")
#         return False

# print("\n проверка стационарности исходного ряда ")
# is_stationary = check_stationarity(ts_data)

# %% [markdown]
# # подготовка данных для ARIMA

# %%
arima_sample_size = 50000
ts_data_subset = data['low'].iloc[-arima_sample_size:].copy()

ts_data_subset = ts_data_subset.iloc[::-1].copy()

original_dates = ts_data_subset.index.copy()

print(f"\n подготовка выборки для ARIMA ")
print(f"размер выборки для ARIMA: {len(ts_data_subset)} записей")
print(f"даты выборки: {original_dates.min()} до {original_dates.max()}")

# разделяем на обучающую и тестовую выборки
# используем 80% для обучения, 20% для тестирования
total_size = len(ts_data_subset)
train_size = int(total_size * 0.8)
test_size = total_size - train_size

train_data = ts_data_subset.iloc[:train_size]
test_data = ts_data_subset.iloc[train_size:]

test_dates = original_dates[train_size:train_size + test_size]

print(f"обучающая выборка: {len(train_data)} записей")
print(f"тестовая выборка: {len(test_data)} записей")
print(f"даты обучения: {train_data.index.min()} до {train_data.index.max()}")
print(f"даты тестирования: {test_data.index.min()} до {test_data.index.max()}")
# Out:
#  подготовка выборки для ARIMA
# размер выборки для ARIMA: 50000 записей
# даты выборки: 2017-08-17 04:00:00 до 2017-09-21 04:18:00
# обучающая выборка: 40000 записей
# тестовая выборка: 10000 записей
# даты обучения: 2017-08-17 04:00:00 до 2017-09-14 05:38:00
# даты тестирования: 2017-09-14 05:39:00 до 2017-09-21 04:18:00

# %% [markdown]
# # реализация ARIMA моделей из статьи

# %%
# %% [markdown]
# # реализация ARIMA моделей из статьи с расчетом R²

# %%
# в статье тестировались модели: ARIMA(1,1,1), (1,1,2), (2,1,0), (2,1,1), (2,1,2)
# наилучшей оказалась ARIMA(2,1,2)

# Функция для расчета R²
def calculate_r2(y_true, y_pred):
    """Коэффициент детерминации R²"""
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    r2 = 1 - (ss_res / ss_tot) if ss_tot != 0 else 0
    return r2

arima_models = {
    'ARIMA(1,1,1)': (1, 1, 1),
    'ARIMA(1,1,2)': (1, 1, 2),
    'ARIMA(2,1,0)': (2, 1, 0),
    'ARIMA(2,1,1)': (2, 1, 1),
    'ARIMA(2,1,2)': (2, 1, 2)
}

results = {}
forecasts = {}

print("\n" + "="*70)
print("Обучение ARIMA моделей:")
print("="*70)

for model_name, order in arima_models.items():
    print(f"\nОбучение {model_name}...")
    try:
        # обучение модели
        model = ARIMA(train_data, order=order)
        model_fit = model.fit()
        
        # прогноз на длину тестовой выборки
        forecast = model_fit.forecast(steps=len(test_data))
        
        # расчет метрик ошибки
        mse = mean_squared_error(test_data, forecast)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(test_data, forecast)
        mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
        r2 = calculate_r2(test_data.values, forecast.values)
        
        # сохранение результатов
        results[model_name] = {
            'model': model_fit,
            'rmse': rmse,
            'mae': mae,
            'mape': mape,
            'r2': r2,
            'mse': mse,
            'aic': model_fit.aic,
            'bic': model_fit.bic
        }
        
        forecasts[model_name] = forecast
        
        print(f"  RMSE: {rmse:.2f}")
        print(f"  MAE: {mae:.2f}")
        print(f"  MAPE: {mape:.2f}%")
        print(f"  R²: {r2:.4f}")
        print(f"  AIC: {model_fit.aic:.2f}")
        print(f"  BIC: {model_fit.bic:.2f}")
        
    except Exception as e:
        print(f"  Ошибка при обучении {model_name}: {e}")
        results[model_name] = None
        forecasts[model_name] = None
# Out:
# ...
# Обучение ARIMA моделей:
# ...
#
# Обучение ARIMA(1,1,1)...
#   RMSE: 276.57
#   MAE: 199.67
#   MAPE: nan%
#   R²: -0.2674
#   AIC: 321966.91
#   BIC: 321992.70
#
# Обучение ARIMA(1,1,2)...
#   RMSE: 277.05
#   MAE: 199.90
#   MAPE: nan%
#   R²: -0.2718
#   AIC: 321930.00
#   BIC: 321964.38
#
# Обучение ARIMA(2,1,0)...
#   RMSE: 276.22
#   MAE: 199.50
#   MAPE: nan%
#   R²: -0.2643
#   AIC: 322366.55
#   BIC: 322392.34
#
# Обучение ARIMA(2,1,1)...
#   RMSE: 276.89
#   MAE: 199.82
#   MAPE: nan%
#   R²: -0.2704
#   AIC: 321939.02
#   BIC: 321973.41
#
# Обучение ARIMA(2,1,2)...
#   RMSE: 277.18
#   MAE: 199.96
#   MAPE: nan%
#   R²: -0.2730
#   AIC: 321918.98
#   BIC: 321961.96

# %% [markdown]
# # сравнение точности ARIMA моделей

# %%
# %% [markdown]
# # сравнение точности ARIMA моделей (двухэтапный подход)

# %%
print("\n" + "="*70)
print("Сравнение ARIMA моделей (двухэтапный подход):")
print("="*70)

# Этап 1: Отбор кандидатов по AIC (на обучающих данных)
print("\n--- ЭТАП 1: Отбор моделей-кандидатов по AIC ---")
print("Сортировка по информационному критерию Акаике (меньше = лучше)")

# Создаем таблицу сравнения с AIC/BIC
comparison_data_aic = []
for model_name, res in results.items():
    if res is not None:
        comparison_data_aic.append({
            'Модель': model_name,
            'AIC': res['aic'],
            'BIC': res['bic'],
            'RMSE': res['rmse'],
            'MAE': res['mae'],
            'MAPE (%)': res['mape']
        })

comparison_df_aic = pd.DataFrame(comparison_data_aic)

# Сортируем по AIC (чем меньше, тем лучше)
comparison_df_aic = comparison_df_aic.sort_values('AIC')
print("\nРанжирование моделей по AIC (на обучающих данных):")
print(comparison_df_aic.to_string(index=False))

# Выбираем топ-N кандидатов по AIC (например, топ-3)
top_n_candidates = 3
top_candidates = comparison_df_aic.head(top_n_candidates)
print(f"\nТоп-{top_n_candidates} кандидатов по AIC:")
print(top_candidates[['Модель', 'AIC', 'BIC']].to_string(index=False))

# Этап 2: Выбор лучшей модели по прогнозным метрикам на тестовой выборке
print("\n--- ЭТАП 2: Выбор лучшей модели по прогнозным метрикам ---")
print("Сравниваем кандидатов по точности прогноза на тестовой выборке")

# Сортируем кандидатов по RMSE (чем меньше, тем лучше)
comparison_df_rmse = comparison_df_aic.copy()
# Фильтруем только топ-кандидатов
top_candidate_names = top_candidates['Модель'].tolist()
top_candidates_comparison = comparison_df_rmse[comparison_df_rmse['Модель'].isin(top_candidate_names)].copy()
top_candidates_comparison = top_candidates_comparison.sort_values('RMSE')

print("\nСравнение кандидатов по прогнозной точности:")
print(top_candidates_comparison.to_string(index=False))

# Определяем лучшую модель
best_arima_model = top_candidates_comparison.iloc[0]['Модель']
best_arima_metrics = results[best_arima_model]

print(f"\nЛучшая ARIMA модель: {best_arima_model}")
print("Выбрана как лучшая по RMSE среди топ-кандидатов по AIC")
print("\nМетрики лучшей модели:")
print(f"  RMSE: {best_arima_metrics['rmse']:.2f}")
print(f"  MAE: {best_arima_metrics['mae']:.2f}")
print(f"  MAPE: {best_arima_metrics['mape']:.2f}%")
print(f"  R²: {best_arima_metrics.get('r2', 'N/A')}")
print(f"  AIC: {best_arima_metrics['aic']:.2f}")
print(f"  BIC: {best_arima_metrics['bic']:.2f}")
# Out:
# ...
# Сравнение ARIMA моделей (двухэтапный подход):
# ...
#
# --- ЭТАП 1: Отбор моделей-кандидатов по AIC ---
# Сортировка по информационному критерию Акаике (меньше = лучше)
#
# Ранжирование моделей по AIC (на обучающих данных):
#       Модель           AIC           BIC       RMSE        MAE  MAPE (%)
# ARIMA(2,1,2) 321918.976854 321961.959903 277.181581 199.959912       NaN
# ARIMA(1,1,2) 321929.995793 321964.382232 277.046696 199.895581       NaN
# ARIMA(2,1,1) 321939.022046 321973.408484 276.892417 199.821837       NaN
# ARIMA(1,1,1) 321966.914405 321992.704235 276.569799 199.667387       NaN
# ARIMA(2,1,0) 322366.545627 322392.335456 276.223892 199.502921       NaN
#
# Топ-3 кандидатов по AIC:
#       Модель           AIC           BIC
# ARIMA(2,1,2) 321918.976854 321961.959903
# ARIMA(1,1,2) 321929.995793 321964.382232
# ARIMA(2,1,1) 321939.022046 321973.408484
#
# --- ЭТАП 2: Выбор лучшей модели по прогнозным метрикам ---
# Сравниваем кандидатов по точности прогноза на тестовой выборке
# ...

# %% [markdown]
# # сохранение результатов

# %%
# %% [markdown]
# # функция для сохранения результатов (с R²)

# %%
def save_arima_results(results_dict, best_model_name, forecasts, test_data, test_dates, train_data, ts_data, filename="arima_results.json"):
    """
    сохраняет результаты ARIMA моделей в json файл
    """
    results_to_save = {
        'best_model': best_model_name,
        'selection_method': 'Two-stage: 1) Top-3 by AIC, 2) Best RMSE among candidates',
        'models_comparison': {},
        'forecasts': {},
        'test_data_info': {}
    }
    
    # сохраняем метрики для всех моделей
    for model_name, res in results_dict.items():
        if res is not None:
            results_to_save['models_comparison'][model_name] = {
                'rmse': float(res['rmse']),
                'mae': float(res['mae']),
                'mape': float(res['mape']),
                'r2': float(res['r2']),
                'mse': float(res['mse']),
                'aic': float(res['aic']),
                'bic': float(res['bic'])
            }
    
    # сохраняем прогнозы лучшей модели
    if best_model_name in forecasts and forecasts[best_model_name] is not None:
        # используем test_dates для дат прогнозов
        if hasattr(test_dates, 'strftime'):
            dates_list = test_dates.strftime('%Y-%m-%d %H:%M:%S').tolist()
        else:
            # если test_dates не DatetimeIndex, создаем список строк
            dates_list = [str(date) for date in test_dates]
            
        results_to_save['forecasts'][best_model_name] = {
            'dates': dates_list,
            'values': forecasts[best_model_name].values.tolist()
        }
    
    # сохраняем информацию о тестовых данных
    results_to_save['test_data_info'] = {
        'train_size': len(train_data),
        'test_size': len(test_data),
        'data_period': f"{ts_data.index.min()} до {ts_data.index.max()}",
        'train_period': f"{train_data.index.min()} до {train_data.index.max()}" if hasattr(train_data.index, 'min') else "недоступно",
        'test_period': f"{test_dates.min()} до {test_dates.max()}" if hasattr(test_dates, 'min') else "недоступно"
    }
    
    # сохраняем в json файл
    with open(filename, 'w') as f:
        json.dump(results_to_save, f, indent=4, ensure_ascii=False)
    
    print(f"\nРезультаты сохранены в файл: {filename}")
    
    return results_to_save

# %% [markdown]
# # визуализация результатов

# %%
# графики прогнозов для всех моделей
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

plot_idx = 0
for idx, (model_name, forecast) in enumerate(forecasts.items()):
    if forecast is not None and plot_idx < 6:
        ax = axes[plot_idx]
        
        # отображаем последние 100 точек обучающих данных
        train_plot = train_data.iloc[-100:] if len(train_data) > 100 else train_data
        
        ax.plot(train_plot.index, train_plot.values, 'b-', label='обучение', alpha=0.7, linewidth=1)
        ax.plot(test_dates, test_data.values, 'k-', label='реальные', alpha=0.7, linewidth=1)
        ax.plot(test_dates, forecast.values, 'r-', label='прогноз', alpha=0.7, linewidth=1)
        
        rmse_val = results[model_name]['rmse']
        ax.set_title(f'{model_name}\nRMSE: {rmse_val:.2f}', fontsize=10)
        ax.legend(loc='upper left', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(axis='x', rotation=45)
        
        plot_idx += 1

# скрываем пустые subplots
for idx in range(plot_idx, 6):
    fig.delaxes(axes[idx])

plt.suptitle('прогнозы ARIMA моделей для минимальной цены биткоина', fontsize=14)
plt.tight_layout()
plt.savefig('results50000/arima_models_forecasts.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # детальный график лучшей модели

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# график 1: прогноз vs факт
ax1.plot(test_dates, test_data.values, 'k-', label='реальные значения', alpha=0.8, linewidth=1.5)
if best_arima_model in forecasts and forecasts[best_arima_model] is not None:
    ax1.plot(test_dates, forecasts[best_arima_model].values, 'r-', 
             label=f'прогноз {best_arima_model}', alpha=0.7, linewidth=1.5)
ax1.set_title(f'прогноз {best_arima_model} на тестовой выборке', fontsize=12)
ax1.set_ylabel('цена (usd)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# график 2: ошибки прогноза
if best_arima_model in forecasts and forecasts[best_arima_model] is not None:
    errors = test_data.values - forecasts[best_arima_model].values
    ax2.plot(test_dates, errors, 'b-', alpha=0.7, linewidth=1)
    ax2.axhline(y=0, color='r', linestyle='--', alpha=0.5)
    
    ax2.fill_between(test_dates, 0, errors, 
                     where=errors >= 0, alpha=0.3, color='red', label='недооценка (прогноз < реального)')
    ax2.fill_between(test_dates, 0, errors, 
                     where=errors < 0, alpha=0.3, color='green', label='переоценка (прогноз > реального)')
    
    ax2.set_title('Ошибки прогноза ARIMA (реальное - прогнозируемое)', fontsize=12)
    ax2.set_xlabel('дата')
    ax2.set_ylabel('ошибка (usd)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('results50000/arima_best_model_forecast.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # выводы

# %%
# %% [markdown]
# # сводная таблица для сравнения с LSTM

# %%
print("\n" + "="*70)
print("Сводная таблица для сравнения с LSTM:")
print("="*70)

# Создаем подробную таблицу сравнения
detailed_comparison_data = []
for model_name, res in results.items():
    if res is not None:
        detailed_comparison_data.append({
            'Модель': model_name,
            'RMSE': f"{res['rmse']:.2f}",
            'MAE': f"{res['mae']:.2f}",
            'MAPE (%)': f"{res['mape']:.2f}",
            'R²': f"{res['r2']:.4f}",
            'AIC': f"{res['aic']:.2f}",
            'BIC': f"{res['bic']:.2f}",
            'Статус': 'Кандидат' if model_name in top_candidate_names else 'Прочие'
        })

detailed_comparison_df = pd.DataFrame(detailed_comparison_data)

# Отмечаем лучшую модель
detailed_comparison_df.loc[detailed_comparison_df['Модель'] == best_arima_model, 'Статус'] = 'Лучшая'

# Сортируем: сначала лучшая, затем кандидаты, затем остальные
status_order = {'Лучшая': 0, 'Кандидат': 1, 'Прочие': 2}
detailed_comparison_df['Статус_порядок'] = detailed_comparison_df['Статус'].map(status_order)
detailed_comparison_df = detailed_comparison_df.sort_values(['Статус_порядок', 'AIC'])
detailed_comparison_df = detailed_comparison_df.drop('Статус_порядок', axis=1)

print("\nПолное сравнение всех моделей:")
print(detailed_comparison_df.to_string(index=False))

# Сохраняем таблицу для сравнения с LSTM
comparison_for_lstm = {
    'best_model': best_arima_model,
    'best_model_metrics': {
        'rmse': float(best_arima_metrics['rmse']),
        'mae': float(best_arima_metrics['mae']),
        'mape': float(best_arima_metrics['mape']),
        'r2': float(best_arima_metrics['r2']),
        'mse': float(best_arima_metrics['mse']),
        'aic': float(best_arima_metrics['aic']),
        'bic': float(best_arima_metrics['bic'])
    },
    'all_models': detailed_comparison_df.to_dict('records'),
    'selection_process': {
        'stage1': 'Отбор топ-3 кандидатов по AIC',
        'stage2': 'Выбор лучшей по RMSE среди кандидатов',
        'top_candidates': top_candidate_names,
        'selected_model': best_arima_model
    }
}

with open('results50000/arima_for_lstm_comparison.json', 'w') as f:
    json.dump(comparison_for_lstm, f, indent=4, ensure_ascii=False)

print("\nДанные для сравнения с LSTM сохранены в: results50000/arima_for_lstm_comparison.json")

# Также сохраняем в CSV
detailed_comparison_df.to_csv('results50000/arima_detailed_comparison.csv', index=False)
print("Детальная таблица сравнения сохранена в: results50000/arima_detailed_comparison.csv")
# Out:
# ...
# Сводная таблица для сравнения с LSTM:
# ...
#
# Полное сравнение всех моделей:
#       Модель   RMSE    MAE MAPE (%)      R²       AIC       BIC   Статус
# ARIMA(2,1,1) 276.89 199.82      nan -0.2704 321939.02 321973.41   Лучшая
# ARIMA(2,1,2) 277.18 199.96      nan -0.2730 321918.98 321961.96 Кандидат
# ARIMA(1,1,2) 277.05 199.90      nan -0.2718 321930.00 321964.38 Кандидат
# ARIMA(1,1,1) 276.57 199.67      nan -0.2674 321966.91 321992.70   Прочие
# ARIMA(2,1,0) 276.22 199.50      nan -0.2643 322366.55 322392.34   Прочие
#
# Данные для сравнения с LSTM сохранены в: results50000/arima_for_lstm_comparison.json
# Детальная таблица сравнения сохранена в: results50000/arima_detailed_comparison.csv

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# 1. График AIC vs BIC
ax1 = axes[0]
models = detailed_comparison_df['Модель']
aic_values = [float(aic) for aic in detailed_comparison_df['AIC']]
bic_values = [float(bic) for bic in detailed_comparison_df['BIC']]

x = np.arange(len(models))
width = 0.35

bars1 = ax1.bar(x - width/2, aic_values, width, label='AIC', color='skyblue', alpha=0.7)
bars2 = ax1.bar(x + width/2, bic_values, width, label='BIC', color='lightcoral', alpha=0.7)

ax1.set_xlabel('Модель')
ax1.set_ylabel('Значение критерия')
ax1.set_title('Сравнение моделей по AIC и BIC\n(чем меньше, тем лучше)')
ax1.set_xticks(x)
ax1.set_xticklabels(models, rotation=45, ha='right')
ax1.legend()

# Подписываем значения
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        ax1.annotate(f'{height:.0f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)

# 2. График метрик точности для кандидатов
ax2 = axes[1]
candidate_df = detailed_comparison_df[detailed_comparison_df['Статус'].isin(['Лучшая', 'Кандидат'])]
candidate_models = candidate_df['Модель']
rmse_values = [float(rmse) for rmse in candidate_df['RMSE']]
mae_values = [float(mae) for mae in candidate_df['MAE']]

x_candidate = np.arange(len(candidate_models))

bars3 = ax2.bar(x_candidate - width/2, rmse_values, width, label='RMSE', color='lightgreen', alpha=0.7)
bars4 = ax2.bar(x_candidate + width/2, mae_values, width, label='MAE', color='orange', alpha=0.7)

ax2.set_xlabel('Модель')
ax2.set_ylabel('Ошибка прогноза')
ax2.set_title('Метрики точности для кандидатов\n(чем меньше, тем лучше)')
ax2.set_xticks(x_candidate)
ax2.set_xticklabels(candidate_models, rotation=45, ha='right')
ax2.legend()

# Выделяем лучшую модель
best_idx = list(candidate_models).index(best_arima_model)
bars3[best_idx].set_color('green')
bars4[best_idx].set_color('darkorange')
bars3[best_idx].set_alpha(1.0)
bars4[best_idx].set_alpha(1.0)

# Подписываем значения
for bars in [bars3, bars4]:
    for bar in bars:
        height = bar.get_height()
        ax2.annotate(f'{height:.1f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)

# 3. График R² и MAPE
ax3 = axes[2]
r2_values = [float(r2) for r2 in detailed_comparison_df['R²']]

x = np.arange(len(models))
line1 = ax3.plot(x, r2_values, 'o-', label='R² (чем больше, тем лучше)', color='blue', linewidth=2)
ax3.set_xlabel('Модель')
ax3.set_ylabel('R²', color='blue')
ax3.set_xticks(x)
ax3.set_xticklabels(models, rotation=45, ha='right')
ax3.tick_params(axis='y', labelcolor='blue')

ax3.set_title('Коэффициент детерминации R² и MAPE')

# Объединяем легенды
lines = line1
labels = [l.get_label() for l in lines]
ax3.legend(lines, labels, loc='upper left')

# Выделяем лучшую модель
ax3.plot(best_idx, r2_values[best_idx], 'o', markersize=10, markerfacecolor='none', 
         markeredgecolor='green', markeredgewidth=3)

plt.tight_layout()
plt.savefig('results50000/arima_model_selection_process.png', dpi=300, bbox_inches='tight')
plt.show()

# Выводы
print("\n" + "="*70)
print("ВЫВОДЫ ОТБОРА МОДЕЛИ:")
print("="*70)
print(f"1. Отобрано топ-{top_n_candidates} кандидатов по AIC: {', '.join(top_candidate_names)}")
print(f"2. Среди кандидатов выбрана лучшая модель по RMSE: {best_arima_model}")
print(f"3. Прогнозная точность лучшей модели:")
print(f"   - RMSE: {best_arima_metrics['rmse']:.2f}")
print(f"   - MAE: {best_arima_metrics['mae']:.2f}")
print(f"   - MAPE: {best_arima_metrics['mape']:.2f}%")
print(f"   - R²: {best_arima_metrics['r2']:.4f}")
print(f"4. Эти метрики будут использованы для сравнения с LSTM моделью")
# Out:
# ...
# ВЫВОДЫ ОТБОРА МОДЕЛИ:
# ...
# 1. Отобрано топ-3 кандидатов по AIC: ARIMA(2,1,2), ARIMA(1,1,2), ARIMA(2,1,1)
# 2. Среди кандидатов выбрана лучшая модель по RMSE: ARIMA(2,1,1)
# 3. Прогнозная точность лучшей модели:
#    - RMSE: 276.89
#    - MAE: 199.82
#    - MAPE: nan%
#    - R²: -0.2704
# 4. Эти метрики будут использованы для сравнения с LSTM моделью

# %% [markdown]
# # прогнозирование на будущие периоды

# %%
# %% [markdown]
# # Прогнозирование на будущие периоды (2, 5, 7, 10 дней вперед) для поминутных данных

# %%
def calculate_minutes_per_period():
    """Рассчитывает количество минут в каждом периоде"""
    minutes_per_day = 24 * 60  # 1440 минут в дне
    
    periods = {
        '2_days': 2 * minutes_per_day,      # 2880 минут
        '5_days': 5 * minutes_per_day,      # 7200 минут
        '7_days': 7 * minutes_per_day,      # 10080 минут
        '10_days': 10 * minutes_per_day     # 14400 минут
    }
    
    return periods

# %%
def forecast_future_minutes(model_fit, periods_dict, last_date, freq='min'):
    """
    Прогнозирование на заданное количество минут вперед
    
    Parameters:
    -----------
    model_fit : обученная модель ARIMA
    periods_dict : словарь с периодами и количеством минут
    last_date : последняя дата в данных
    freq : частота данных ('min' для минутных)
    
    Returns:
    --------
    dict: словарь с прогнозами для каждого периода
    """
    forecasts = {}
    
    for period_name, minutes in periods_dict.items():
        print(f"  Прогнозирование для {period_name} ({minutes} минут)...")
        
        try:
            # Создаем прогноз на minutes минут вперед
            forecast = model_fit.forecast(steps=int(minutes))
            
            # Создаем даты для прогноза
            if isinstance(last_date, pd.Timestamp):
                forecast_dates = pd.date_range(
                    start=last_date + pd.Timedelta(minutes=1),
                    periods=int(minutes),
                    freq='min'
                )
            else:
                # Если last_date не Timestamp, создаем индексы
                forecast_dates = [f'Minute_{i+1}' for i in range(int(minutes))]
            
            forecasts[period_name] = {
                'minutes': minutes,
                'days': minutes / (24 * 60),  # Преобразуем в дни
                'dates': forecast_dates,
                'values': forecast.values if hasattr(forecast, 'values') else forecast,
                'forecast_obj': forecast
            }
            
            print(f"    Успешно создано {len(forecast)} прогнозов")
            
        except Exception as e:
            print(f"    Ошибка при прогнозировании {period_name}: {e}")
            forecasts[period_name] = None
    
    return forecasts

# %%
# Загружаем дополнительные данные для проверки прогнозов
print("\nЗагрузка дополнительных данных для проверки прогнозов...")

# Предполагаем, что у вас есть исходный файл с данными
try:
    # Получаем последнюю дату в наших данных
    last_date_in_data = ts_data_subset.index.max()
    print(f"Последняя дата в текущих данных: {last_date_in_data}")
    
    # Проверяем тип данных
    print(f"Тип last_date_in_data: {type(last_date_in_data)}")
    print(f"Первые 5 записей ts_data_subset:")
    print(ts_data_subset.head())
    print(f"Последние 5 записей ts_data_subset:")
    print(ts_data_subset.tail())
    
    # Проверяем частоту данных
    try:
        freq_info = pd.infer_freq(ts_data_subset.index[:10])
        print(f"Определенная частота данных: {freq_info}")
    except:
        print("Не удалось определить частоту данных автоматически")
    
    # Загружаем полный датасет
    print("\nЗагрузка полного датасета...")
    full_data = pd.read_csv('bitcoin_2017_to_2023.csv')
    print(f"Размер полного датасета: {full_data.shape}")
    
    full_data['timestamp'] = pd.to_datetime(full_data['timestamp'])
    full_data.set_index('timestamp', inplace=True)
    full_ts_data = full_data['low'].copy()
    
    print(f"\nИнформация о полном датасете:")
    print(f"Размер: {len(full_ts_data)} записей")
    print(f"Период: {full_ts_data.index.min()} до {full_ts_data.index.max()}")
    
    # Находим данные, которые идут после last_date_in_data
    future_data = full_ts_data[full_ts_data.index > last_date_in_data]
    
    if len(future_data) > 0:
        print(f"\nНайдено {len(future_data)} записей после тестового периода")
        print(f"Период будущих данных: {future_data.index.min()} до {future_data.index.max()}")
        
        # Рассчитываем периоды в минутах
        periods_dict = calculate_minutes_per_period()
        
        # Создаем словарь с реальными данными для каждого периода
        real_future_data = {}
        
        for period_name, minutes in periods_dict.items():
            days = minutes / (24 * 60)
            if len(future_data) >= minutes:
                real_future_data[period_name] = future_data.iloc[:int(minutes)]
                print(f"  Реальные данные для {period_name} ({days:.1f} дней, {minutes} минут): {len(real_future_data[period_name])} записей")
            else:
                print(f"  Внимание: Недостаточно данных для проверки {period_name} ({minutes} минут)")
                real_future_data[period_name] = None
    else:
        print("Не найдено данных после тестового периода")
        real_future_data = None
        
except Exception as e:
    print(f"Ошибка при загрузке будущих данных: {e}")
    import traceback
    traceback.print_exc()
    real_future_data = None

# %%
# Переобучаем лучшую модель на всех данных для лучшего прогнозирования
print(f"\nПереобучение лучшей модели {best_arima_model} на всех данных...")

# Используем параметры лучшей модели
best_order = arima_models[best_arima_model]

# Обучаем на всех данных (train + test)
full_train_data = pd.concat([train_data, test_data])

# Проверяем данные перед обучением
print(f"Размер full_train_data: {len(full_train_data)}")
print(f"Первые 3 значения: {full_train_data.iloc[:3].values}")
print(f"Последние 3 значения: {full_train_data.iloc[-3:].values}")

# Обучение модели на всех данных
try:
    full_model = ARIMA(full_train_data, order=best_order)
    full_model_fit = full_model.fit()
    
    print(f"Модель переобучена на {len(full_train_data)} записях")
    print(f"Период переобученных данных: {full_train_data.index.min()} до {full_train_data.index.max()}")
    print(f"Последняя дата: {full_train_data.index.max()}")
    
except Exception as e:
    print(f"Ошибка при обучении модели: {e}")
    import traceback
    traceback.print_exc()

# %%
# Прогнозирование на будущие периоды (в минутах)
print("\nПрогнозирование на будущие периоды (в минутах)...")

# Рассчитываем периоды в минутах
periods_dict = calculate_minutes_per_period()

# Получаем последнюю дату для прогнозирования
last_date = full_train_data.index.max()
print(f"Последняя дата для прогноза: {last_date}")
print(f"Тип last_date: {type(last_date)}")

# Создаем прогнозы
future_forecasts = forecast_future_minutes(full_model_fit, periods_dict, last_date)

# Проверяем созданные прогнозы
print("\nПроверка созданных прогнозов:")
for period_name, forecast_info in future_forecasts.items():
    if forecast_info is not None:
        minutes = forecast_info['minutes']
        days = forecast_info['days']
        values = forecast_info['values']
        print(f"  {period_name}: {days:.1f} дней ({minutes} минут)")
        print(f"    Количество прогнозов: {len(values) if hasattr(values, '__len__') else 'N/A'}")
        print(f"    Первые 3 значения: {values[:3] if len(values) >= 3 else values}")
        print(f"    Последние 3 значения: {values[-3:] if len(values) >= 3 else values}")
    else:
        print(f"  {period_name}: Прогноз не создан")

# %%
# Сравнение прогнозов с реальными данными (если есть)
print("\n" + "="*70)
print("Сравнение прогнозов с реальными данными:")
print("="*70)

# Создаем словарь для удобного вывода названий периодов
period_names_display = {
    '2_days': '2 дня',
    '5_days': '5 дней',
    '7_days': '7 дней',
    '10_days': '10 дней'
}

comparison_results = {}

if real_future_data:
    for period_name, minutes in periods_dict.items():
        if future_forecasts.get(period_name) is not None and real_future_data.get(period_name) is not None:
            try:
                forecast_values = future_forecasts[period_name]['values']
                actual_values = real_future_data[period_name].values
                
                # Проверяем размеры
                if len(forecast_values) != len(actual_values):
                    print(f"  Размеры не совпадают для {period_name}: прогноз={len(forecast_values)}, факт={len(actual_values)}")
                    # Берем минимум из двух
                    min_len = min(len(forecast_values), len(actual_values))
                    forecast_values = forecast_values[:min_len]
                    actual_values = actual_values[:min_len]
                
                # Вычисляем метрики
                mse = mean_squared_error(actual_values, forecast_values)
                rmse = np.sqrt(mse)
                mae = mean_absolute_error(actual_values, forecast_values)
                mape = np.mean(np.abs((actual_values - forecast_values) / actual_values)) * 100
                
                comparison_results[period_name] = {
                    'period_display': period_names_display[period_name],
                    'minutes': minutes,
                    'days': minutes / (24 * 60),
                    'rmse': rmse,
                    'mae': mae,
                    'mape': mape,
                    'mse': mse,
                    'actual_values': actual_values.tolist(),
                    'forecast_values': forecast_values.tolist(),
                    'dates': [d.strftime('%Y-%m-%d %H:%M') for d in real_future_data[period_name].index[:len(actual_values)]]
                }
                
                print(f"\n{period_names_display[period_name]} ({minutes} минут):")
                print(f"  RMSE: {rmse:.2f}")
                print(f"  MAE: {mae:.2f}")
                print(f"  MAPE: {mape:.2f}%")
                print(f"  Период: {real_future_data[period_name].index[0]} до {real_future_data[period_name].index[min_len-1]}")
                
            except Exception as e:
                print(f"  Ошибка при сравнении для {period_name}: {e}")
else:
    print("Реальные данные для сравнения отсутствуют")
    
    # Выводим только прогнозы
    for period_name, forecast_info in future_forecasts.items():
        if forecast_info is not None:
            days = forecast_info['days']
            minutes = forecast_info['minutes']
            print(f"\n{period_names_display[period_name]} ({minutes} минут):")
            if hasattr(forecast_info['dates'], '__len__') and len(forecast_info['dates']) > 0:
                print(f"  Период прогноза: {forecast_info['dates'][0]} до {forecast_info['dates'][-1]}")
            else:
                print("  Даты прогноза не определены")

# %%
# ОПТИМИЗАЦИЯ: Фильтруем данные до конца 2018 года для графиков
print("\n" + "="*70)
print("ОПТИМИЗАЦИЯ: Фильтрация данных для графиков до конца 2018 года")
print("="*70)

# Определяем дату конца 2018 года
end_2018 = pd.Timestamp('2018-12-31 23:59:59')

# Фильтруем исторические данные до конца 2018 года
filtered_train_data = full_train_data[full_train_data.index <= end_2018]

print(f"Исходный размер исторических данных: {len(full_train_data)}")
print(f"Отфильтрованный размер (до конца 2018): {len(filtered_train_data)}")
print(f"Диапазон отфильтрованных данных: {filtered_train_data.index.min()} до {filtered_train_data.index.max()}")

# Если отфильтрованных данных слишком мало, используем последние 1000 точек
if len(filtered_train_data) < 100:
    print("Отфильтрованных данных слишком мало, используем последние 1000 точек")
    filtered_train_data = full_train_data.iloc[-1000:] if len(full_train_data) > 1000 else full_train_data

# %%
# Визуализация прогнозов на будущие периоды с ограниченным масштабом
print("\nСоздание визуализаций с ограниченным масштабом (до конца 2018)...")

# Создаем один график для каждого периода
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()

# Проверяем, что у нас есть прогнозы
valid_forecasts = [name for name, info in future_forecasts.items() if info is not None]
print(f"Доступные прогнозы для визуализации: {valid_forecasts}")

for idx, period_name in enumerate(['2_days', '5_days', '7_days', '10_days']):
    ax = axes[idx]
    
    if period_name in future_forecasts and future_forecasts[period_name] is not None:
        forecast_info = future_forecasts[period_name]
        
        # Берем только последние 500 точек исторических данных для наглядности
        history_to_show = filtered_train_data.iloc[-500:] if len(filtered_train_data) > 500 else filtered_train_data
        
        # 1. Исторические данные (синяя линия)
        if len(history_to_show) > 0:
            ax.plot(history_to_show.index, history_to_show.values, 'b-', 
                    label='Исторические данные', alpha=0.7, linewidth=1)
        
        # 2. Прогноз (красная линия)
        forecast_values = forecast_info['values']
        forecast_dates = forecast_info['dates']
        
        if hasattr(forecast_values, '__len__') and len(forecast_values) > 0:
            # Для прогнозов берем только первые 100 точек для наглядности
            plot_limit = min(100, len(forecast_values))
            
            # Конвертируем даты прогнозов в тот же формат
            if hasattr(forecast_dates, '__len__'):
                # Создаем временную ось для прогнозов, начиная с последней исторической точки
                last_historical_date = history_to_show.index[-1] if len(history_to_show) > 0 else last_date
                
                if isinstance(last_historical_date, pd.Timestamp):
                    # Создаем новые даты для прогноза, начиная с последней исторической
                    forecast_time_axis = pd.date_range(
                        start=last_historical_date + pd.Timedelta(minutes=1),
                        periods=plot_limit,
                        freq='min'
                    )
                    
                    ax.plot(forecast_time_axis, forecast_values[:plot_limit], 'r-', 
                            label='Прогноз', alpha=0.7, linewidth=1.5, marker='.')
        
        # 3. Реальные данные (зеленая линия, если есть)
        if real_future_data and period_name in real_future_data and real_future_data[period_name] is not None:
            real_values = real_future_data[period_name].values
            real_dates = real_future_data[period_name].index
            
            plot_limit_real = min(100, len(real_values))
            
            # Создаем временную ось для реальных данных
            if len(history_to_show) > 0:
                real_time_axis = pd.date_range(
                    start=history_to_show.index[-1] + pd.Timedelta(minutes=1),
                    periods=plot_limit_real,
                    freq='min'
                )
                
                ax.plot(real_time_axis, real_values[:plot_limit_real], 'g-', 
                        label='Реальные данные', alpha=0.7, linewidth=1.5, marker='^')
        
        # Настройки графика
        days = forecast_info['days']
        ax.set_title(f'Прогноз на {period_names_display[period_name]}', fontsize=12)
        ax.set_xlabel('Дата (ограничено до конца 2018)')
        ax.set_ylabel('Цена (USD)')
        ax.legend(loc='best', fontsize=9)
        ax.grid(True, alpha=0.3)
        
        # Устанавливаем пределы оси X для лучшего отображения
        if len(history_to_show) > 0:
            # Берем диапазон исторических данных
            x_min = history_to_show.index[0]
            x_max = history_to_show.index[-1] + pd.Timedelta(days=2)  # Добавляем немного для прогнозов
            
            # Убедимся, что не выходим за пределы 2018 года
            if x_max > end_2018:
                x_max = end_2018
            
            ax.set_xlim([x_min, x_max])
        
        # Добавляем метрики, если есть
        if period_name in comparison_results:
            rmse = comparison_results[period_name]['rmse']
            ax.text(0.02, 0.95, f'RMSE: {rmse:.2f}', transform=ax.transAxes, 
                   fontsize=9, verticalalignment='top',
                   bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        # Поворачиваем метки дат
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')
    else:
        ax.text(0.5, 0.5, f'Прогноз для {period_names_display[period_name]} не доступен', 
                transform=ax.transAxes, ha='center', va='center', fontsize=11)
        ax.set_title(f'Прогноз на {period_names_display[period_name]}', fontsize=12)
        ax.grid(True, alpha=0.3)

plt.suptitle('Прогнозы ARIMA модели на различные периоды вперед (масштаб до конца 2018)', fontsize=14)
plt.tight_layout()
plt.savefig('results50000/arima_future_forecasts_2018_scale.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# АЛЬТЕРНАТИВНАЯ ВИЗУАЛИЗАЦИЯ: Агрегированные данные (по часам или дням)
print("\nСоздание агрегированных визуализаций...")

# Агрегируем исторические данные по дням
daily_history = filtered_train_data.resample('D').mean()

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()

for idx, period_name in enumerate(['2_days', '5_days', '7_days', '10_days']):
    ax = axes[idx]
    
    if period_name in future_forecasts and future_forecasts[period_name] is not None:
        forecast_info = future_forecasts[period_name]
        
        # Берем последние 30 дней исторических данных
        history_to_show = daily_history.iloc[-30:] if len(daily_history) > 30 else daily_history
        
        # 1. Исторические данные (синяя линия)
        if len(history_to_show) > 0:
            ax.plot(history_to_show.index, history_to_show.values, 'b-', 
                    label='Средняя цена за день', alpha=0.7, linewidth=2, marker='o')
        
        # 2. Прогноз (агрегируем по дням)
        forecast_values = forecast_info['values']
        
        if hasattr(forecast_values, '__len__') and len(forecast_values) > 0:
            # Агрегируем прогноз по дням (среднее за день)
            # Создаем временной ряд прогнозов
            forecast_series = pd.Series(
                forecast_values, 
                index=forecast_info['dates'][:len(forecast_values)]
            )
            
            # Агрегируем по дням
            daily_forecast = forecast_series.resample('D').mean()
            
            # Продолжаем временную ось с последней исторической точки
            if len(history_to_show) > 0:
                last_hist_date = history_to_show.index[-1]
                # Создаем новые даты для прогноза
                forecast_dates = pd.date_range(
                    start=last_hist_date + pd.Timedelta(days=1),
                    periods=len(daily_forecast),
                    freq='D'
                )
                
                ax.plot(forecast_dates, daily_forecast.values, 'r-', 
                        label='Прогноз (среднее за день)', alpha=0.7, linewidth=2, marker='s')
        
        # Настройки графика
        days = forecast_info['days']
        ax.set_title(f'Агрегированный прогноз на {period_names_display[period_name]}', fontsize=12)
        ax.set_xlabel('Дата')
        ax.set_ylabel('Средняя цена за день (USD)')
        ax.legend(loc='best')
        ax.grid(True, alpha=0.3)
        
        # Добавляем метрики, если есть
        if period_name in comparison_results:
            rmse = comparison_results[period_name]['rmse']
            ax.text(0.02, 0.95, f'RMSE (минутный): {rmse:.2f}', transform=ax.transAxes, 
                   fontsize=9, verticalalignment='top',
                   bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        # Форматируем даты
        ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')
    else:
        ax.text(0.5, 0.5, f'Прогноз не доступен', 
                transform=ax.transAxes, ha='center', va='center', fontsize=11)
        ax.set_title(f'Прогноз на {period_names_display[period_name]}', fontsize=12)
        ax.grid(True, alpha=0.3)

plt.suptitle('Агрегированные дневные прогнозы ARIMA модели', fontsize=14)
plt.tight_layout()
plt.savefig('results50000/arima_daily_aggregated_forecasts.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Сводная таблица с метриками прогнозов
if comparison_results:
    print("\n" + "="*70)
    print("Сводная таблица метрик прогнозов:")
    print("="*70)
    
    summary_data = []
    for period_name, metrics in comparison_results.items():
        summary_data.append({
            'Период': metrics['period_display'],
            'Минут': int(metrics['minutes']),
            'Дней': f"{metrics['days']:.1f}",
            'RMSE': f"{metrics['rmse']:.2f}",
            'MAE': f"{metrics['mae']:.2f}",
            'MAPE (%)': f"{metrics['mape']:.2f}",
            'MSE': f"{metrics['mse']:.2f}"
        })
    
    summary_df = pd.DataFrame(summary_data)
    print("\n", summary_df.to_string(index=False))
    
    # Сохраняем сводную таблицу
    summary_df.to_csv('results50000/arima_forecast_metrics_summary_minutes.csv', index=False)
    print("\nСводная таблица сохранена в: results50000/arima_forecast_metrics_summary_minutes.csv")
    
    # Визуализация RMSE для разных горизонтов прогноза
    plt.figure(figsize=(10, 6))
    
    periods = summary_df['Период']
    rmse_values = [float(r) for r in summary_df['RMSE']]
    
    bars = plt.bar(periods, rmse_values, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
    plt.xlabel('Период прогноза')
    plt.ylabel('RMSE')
    plt.title('Зависимость ошибки прогноза (RMSE) от горизонта прогнозирования')
    plt.grid(True, alpha=0.3, axis='y')
    
    # Добавляем значения на столбцы
    for bar, rmse in zip(bars, rmse_values):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.05,
                f'{rmse:.2f}', ha='center', va='bottom')
    
    plt.tight_layout()
    plt.savefig('results50000/arima_forecast_horizon_rmse_minutes.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # График зависимости RMSE от количества дней
    plt.figure(figsize=(10, 6))
    days_list = [float(d) for d in summary_df['Дней']]
    plt.plot(days_list, rmse_values, 'bo-', linewidth=2, markersize=8)
    plt.xlabel('Горизонт прогноза (дни)')
    plt.ylabel('RMSE')
    plt.title('Зависимость RMSE от горизонта прогнозирования (в днях)')
    plt.grid(True, alpha=0.3)
    
    # Добавляем аннотации
    for i, (days, rmse, period) in enumerate(zip(days_list, rmse_values, periods)):
        plt.annotate(f'{period}\nRMSE: {rmse:.2f}', 
                    (days, rmse),
                    textcoords="offset points",
                    xytext=(0,10),
                    ha='center',
                    fontsize=9)
    
    plt.tight_layout()
    plt.savefig('results50000/arima_rmse_vs_days.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# Сохранение всех прогнозов в JSON файл
print("\nСохранение прогнозов на будущие периоды...")

forecasts_to_save = {
    'best_model': best_arima_model,
    'best_order': best_order,
    'forecast_horizons': {},
    'comparison_metrics': comparison_results if comparison_results else {},
    'periods_minutes': periods_dict,
    'data_info': {
        'original_frequency': 'minute',
        'minutes_per_day': 24 * 60,
        'training_data_size': len(full_train_data),
        'last_training_date': str(last_date),
        'training_data_range': f"{full_train_data.index.min()} до {full_train_data.index.max()}",
        'filtered_for_plots': f"Данные для графиков ограничены до {end_2018.date()}"
    }
}

# Сохраняем прогнозы
for period_name, forecast_info in future_forecasts.items():
    if forecast_info is not None:
        forecasts_to_save['forecast_horizons'][period_name] = {
            'minutes': int(forecast_info['minutes']),
            'days': float(forecast_info['days']),
            'values': [float(val) for val in forecast_info['values']]
        }
        
        # Сохраняем даты, если они есть
        if hasattr(forecast_info['dates'], '__len__') and len(forecast_info['dates']) > 0:
            try:
                dates_str = [d.strftime('%Y-%m-%d %H:%M:%S') if hasattr(d, 'strftime') else str(d) 
                            for d in forecast_info['dates']]
                forecasts_to_save['forecast_horizons'][period_name]['dates'] = dates_str
            except:
                forecasts_to_save['forecast_horizons'][period_name]['dates'] = [str(d) for d in forecast_info['dates']]

# Сохраняем в файл
with open('results50000/arima_future_forecasts_minutes.json', 'w') as f:
    json.dump(forecasts_to_save, f, indent=4, ensure_ascii=False)

print("Прогнозы на будущие периоды сохранены в: results50000/arima_future_forecasts_minutes.json")

# %%
# Финальный анализ и выводы
print("\n" + "="*70)
print("ФИНАЛЬНЫЕ ВЫВОДЫ:")
print("="*70)

print(f"\nЛучшая модель: {best_arima_model}")
print(f"Параметры модели: ARIMA{best_order}")
print(f"Размер обучающей выборки: {len(full_train_data)} минутных записей")
print(f"Для визуализации использованы данные до: {end_2018.date()}")

if comparison_results:
    print("\nАнализ способности модели прогнозировать на разные периоды:")
    
    # Сортируем периоды по RMSE
    sorted_periods = sorted(comparison_results.items(), 
                           key=lambda x: x[1]['rmse'])
    
    for period_name, metrics in sorted_periods:
        rmse = metrics['rmse']
        mape = metrics['mape']
        minutes = metrics['minutes']
        days = metrics['days']
        print(f"\n  {metrics['period_display']} ({minutes} минут):")
        print(f"    RMSE: {rmse:.2f}")
        print(f"    MAPE: {mape:.2f}%")
        print(f"    Охватывает период: {days:.1f} дней")
    
    if len(sorted_periods) >= 2:
        best_period = sorted_periods[0][1]['period_display']
        worst_period = sorted_periods[-1][1]['period_display']
        best_rmse = sorted_periods[0][1]['rmse']
        worst_rmse = sorted_periods[-1][1]['rmse']
        
        print(f"\nВыводы:")
        print(f"  1. Лучший горизонт прогноза: {best_period} (RMSE = {best_rmse:.2f})")
        print(f"  2. Худший горизонт прогноза: {worst_period} (RMSE = {worst_rmse:.2f})")
        print(f"  3. Точность прогноза снижается с увеличением горизонта прогнозирования")
        
        # Анализ тренда ошибок
        if len(sorted_periods) > 1:
            rmse_increase = ((worst_rmse / best_rmse) - 1) * 100
            print(f"  4. RMSE увеличивается на {rmse_increase:.1f}% при увеличении горизонта прогноза")
else:
    print("\nПрогнозы на будущие периоды созданы успешно.")
    print(f"Созданы прогнозы на: {', '.join([f'{k} ({v["days"]:.1f} дней)' for k, v in future_forecasts.items() if v is not None])}")
    print("\nДля анализа точности необходимы реальные данные за эти периоды.")

print("\n" + "="*70)
print("Анализ завершен!")
print("="*70)
# Out:
# Загрузка дополнительных данных для проверки прогнозов...
# Последняя дата в текущих данных: 2017-09-21 04:18:00
# Тип last_date_in_data: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# Первые 5 записей ts_data_subset:
# timestamp
# 2017-08-17 04:00:00    4261.48
# 2017-08-17 04:01:00    4261.48
# 2017-08-17 04:02:00    4280.56
# 2017-08-17 04:03:00    4261.48
# 2017-08-17 04:04:00    4261.48
# Name: low, dtype: float64
# Последние 5 записей ts_data_subset:
# timestamp
# 2017-09-21 04:14:00    3819.99
# 2017-09-21 04:15:00    3820.00
# 2017-09-21 04:16:00    3827.63
# 2017-09-21 04:17:00    3827.64
# 2017-09-21 04:18:00    3813.87
# Name: low, dtype: float64
# Определенная частота данных: min
#
# Загрузка полного датасета...
# Размер полного датасета: (3126000, 10)
#
# Информация о полном датасете:
# Размер: 3126000 записей
# Период: 2017-08-17 04:00:00 до 2023-08-01 13:19:00
#
# Найдено 3076000 записей после тестового периода
# ...
